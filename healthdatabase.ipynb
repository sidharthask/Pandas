# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/nchs (1).csv")

# %%
data
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10296 entries, 0 to 10295
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     10296 non-null  int64
#  1   113 Cause Name           10296 non-null  object
#  2   Cause Name               10296 non-null  object
#  3   State                    10296 non-null  object
#  4   Deaths                   10296 non-null  int64
#  5   Age-adjusted Death Rate  10296 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 482.8+ KB

# %%
data["Cause Name"].unique()
# Out:
# array(['Unintentional injuries', 'All causes', "Alzheimer's disease",
#        'Cancer', 'CLRD', 'Diabetes', 'Heart disease',
#        'Influenza and pneumonia', 'Kidney disease', 'Stroke', 'Suicide'],
#       dtype=object)

# %%
(data[data["Cause Name"]!="All causes"])
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
data["State"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'United States'],
#       dtype=object)

# %%
st=data.groupby("State").sum()

# %%
print(st)
# Out:
#                         Year    Deaths  Age-adjusted Death Rate
# State
# Alabama               397485   1510931                  30446.7
# Alaska                397485    110361                  24462.6
# Arizona               397485   1471757                  23278.0
# Arkansas              397485    929634                  29442.7
# California            397485   7694563                  22415.2
# Colorado              397485    973746                  22575.7
# Connecticut           397485    927612                  21981.2
# Delaware              397485    238935                  25367.4
# District of Columbia  397485    160361                  27437.4
# Florida               397485   5512136                  23067.3
# Georgia               397485   2182235                  27467.6
# Hawaii                397485    300668                  19696.3
# Idaho                 397485    351070                  24038.2
# Illinois              397485   3299528                  25044.8
# ...

# %%
top=st.sort_values("Deaths", ascending=True)

# %%
Top=top.head(10)

# %%
Top
# Out:
#                         Year  Deaths  Age-adjusted Death Rate
# State
# Alaska                397485  110361                  24462.6
# Wyoming               397485  136865                  25383.6
# District of Columbia  397485  160361                  27437.4
# Vermont               397485  168797                  23610.4
# North Dakota          397485  191032                  23140.2
# South Dakota          397485  230111                  23918.6
# Delaware              397485  238935                  25367.4
# Montana               397485  277255                  24817.1
# Hawaii                397485  300668                  19696.3
# Rhode Island          397485  310105                  23755.7

# %%
topc=(data[data["Cause Name"]!="All causes"])

# %%
topc
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...     ...                                                ...
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name       State  Deaths  Age-adjusted Death Rate
# 0      Unintentional injuries     Alabama    2755                     55.5
# ...

# %%
topcs=data.groupby("Cause Name").sum()

# %%
topcs
# Out:
#                             Year    Deaths  Age-adjusted Death Rate
# Cause Name
# All causes               1879020  89405359                 749665.1
# Alzheimer's disease      1879020   2746824                  23043.1
# CLRD                     1879020   4869452                  41787.4
# Cancer                   1879020  20489072                 168385.3
# Diabetes                 1879020   2632758                  21969.7
# Heart disease            1879020  23150366                 186996.3
# Influenza and pneumonia  1879020   2077938                  17212.2
# Kidney disease           1879020   1615960                  13234.5
# Stroke                   1879020   5160280                  43391.4
# Suicide                  1879020   1299686                  12388.4
# Unintentional injuries   1879020   4355768                  40086.7

# %%
sot=topcs.sort_values("Deaths", ascending=False)

# %%
sot[1:]
# Out:
#                             Year    Deaths  Age-adjusted Death Rate
# Cause Name
# Heart disease            1879020  23150366                 186996.3
# Cancer                   1879020  20489072                 168385.3
# Stroke                   1879020   5160280                  43391.4
# CLRD                     1879020   4869452                  41787.4
# Unintentional injuries   1879020   4355768                  40086.7
# Alzheimer's disease      1879020   2746824                  23043.1
# Diabetes                 1879020   2632758                  21969.7
# Influenza and pneumonia  1879020   2077938                  17212.2
# Kidney disease           1879020   1615960                  13234.5
# Suicide                  1879020   1299686                  12388.4

# %%
sot.mean()
# Out:
# Year                       1.879020e+06
# Deaths                     1.434577e+07
# Age-adjusted Death Rate    1.198327e+05
# dtype: float64
